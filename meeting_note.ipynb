# %%
import pandas as pd

# %%
articles = pd.read_csv("articles.csv")
articles
# Out:
#         article_id  product_code               prod_name  product_type_no  \
# 0        108775015        108775               Strap top              253
# 1        108775044        108775               Strap top              253
# 2        108775051        108775           Strap top (1)              253
# 3        110065001        110065       OP T-shirt (Idro)              306
# 4        110065002        110065       OP T-shirt (Idro)              306
# ...            ...           ...                     ...              ...
# 105537   953450001        953450  5pk regular Placement1              302
# 105538   953763001        953763       SPORT Malaga tank              253
# 105539   956217002        956217         Cartwheel dress              265
# 105540   957375001        957375        CLAIRE HAIR CLAW               72
# 105541   959461001        959461            Lounge dress              265
#
#        product_type_name  product_group_name  graphical_appearance_no  \
# ...

# %%
print("article id: ",len(articles.article_id.unique()),"Prod Code: ",len(articles.product_code.unique()),"Product type: ",len(articles.product_type_no.unique()))
# Out:
# article id:  105542 Prod Code:  47224 Product type:  132

# %%
customers = pd.read_csv("customers.csv")
customers
# Out:
#                                                customer_id   FN  Active  \
# 0        00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...  NaN     NaN
# 1        0000423b00ade91418cceaf3b26c6af3dd342b51fd051e...  NaN     NaN
# 2        000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...  NaN     NaN
# 3        00005ca1c9ed5f5146b52ac8639a40ca9d57aeff4d1bd2...  NaN     NaN
# 4        00006413d8573cd20ed7128e53b7b13819fe5cfc2d801f...  1.0     1.0
# ...                                                    ...  ...     ...
# 1371975  ffffbbf78b6eaac697a8a5dfbfd2bfa8113ee5b403e474...  NaN     NaN
# 1371976  ffffcd5046a6143d29a04fb8c424ce494a76e5cdf4fab5...  NaN     NaN
# 1371977  ffffcf35913a0bee60e8741cb2b4e78b8a98ee5ff2e6a1...  1.0     1.0
# 1371978  ffffd7744cebcf3aca44ae7049d2a94b87074c3d4ffe38...  1.0     1.0
# 1371979  ffffd9ac14e89946416d80e791d064701994755c3ab686...  NaN     NaN
#
#         club_member_status fashion_news_frequency   age  \
# ...

# %%
print("postal_code: ",len(customers.postal_code.unique()))# whoa
# Out:
# postal_code:  352899

# %%
transaction1 = pd.read_csv("transaction1.csv") # random forest, LDA, Naive Bayes
transaction1 

# would like to add one more variable, the decoded postal code 
# after we shrink the dimension of the article_id, plase do the statistical test, for time series data
#
# Out:
#          Unnamed: 0       t_dat  \
# 0                 0  2018-09-20
# 1                 1  2018-09-20
# 2                 2  2018-09-20
# 3                 3  2018-09-20
# 4                 4  2018-09-20
# ...             ...         ...
# 3178827     3178827  2018-11-28
# 3178828     3178828  2018-11-28
# 3178829     3178829  2018-11-28
# 3178830     3178830  2018-11-28
# 3178831     3178831  2018-11-28
#
#                                                customer_id  article_id  \
# 0        000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...   663713001
# 1        000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...   541518023
# 2        00007d2de826758b65a93dd24ce629ed66842531df6699...   505221004
# 3        00007d2de826758b65a93dd24ce629ed66842531df6699...   685687003
# 4        00007d2de826758b65a93dd24ce629ed66842531df6699...   685687004
# ...                                                    ...         ...
# 3178827  475f4a95d432dc7b33464c2936df871b0b8b762311fc6d...   669896004
# ...

# %% [markdown]
# # EDA
#  - Article dimension shrinkage
#  - statistical test (multinomial test, Goodness of fit) to - Julie

# %% [markdown]
# # Machine learning
#  - decoding algorithm (fist total, after shrinkage, after Stat Test)
#  - apply LDA, RF, Naive Bayes, possibly SVM
